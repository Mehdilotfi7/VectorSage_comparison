# %%
# Cell 1: Imports, Model Loading, and Explicit Encoding Function
import json
import torch
import torch.nn.functional as F
import pandas as pd
import numpy as np
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity

# Define the model checkpoint
MODEL_NAME = "sentence-transformers/all-mpnet-base-v2"

# Load tokenizer and model from Hugging Face
print(f"Loading tokenizer and model: {MODEL_NAME}...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)
print("Model loaded successfully.")
# Out:
# Loading tokenizer and model: sentence-transformers/all-mpnet-base-v2...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded successfully.

# %%
def encode_texts(texts):
    """Encodes a list of strings into L2-normalized dense embeddings
    using explicitly implemented mean pooling and attention masking.
    """
    # Ensure we always have a list
    if isinstance(texts, str):
        texts = [texts]

    # Tokenize input texts
    encoded_input = tokenizer(
        texts,
        padding=True,
        truncation=True,
        return_tensors="pt",
    )

    # Compute token embeddings
    with torch.no_grad():
        model_output = model(**encoded_input)

    # Mean Pooling Logic
    token_embeddings = model_output[0]
    attention_mask = encoded_input["attention_mask"]
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()

    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    pooled_embeddings = sum_embeddings / sum_mask

    # L2 Normalization
    normalized_embeddings = F.normalize(pooled_embeddings, p=2, dim=1)

    return normalized_embeddings.numpy()

# %%
sent1 = "I am alive"
sent2 = "I am dead"


doc_embs1 = encode_texts(sent1)
doc_embs2 = encode_texts(sent2)
doc_embs3 = doc_embs1 - doc_embs2

sim_normal1 = cosine_similarity(doc_embs1, doc_embs2)[0]
sim_normal2 = cosine_similarity(doc_embs1, doc_embs3)[0]

sim_normal1, sim_normal2
# Out:
# (array([0.6230484], dtype=float32), array([0.43413803], dtype=float32))

# %%
import numpy as np

def build_concept_vector(words):
    embs = encode_texts(words)
    u = embs.mean(axis=0)
    u = u / np.linalg.norm(u)
    return u

life_concept = build_concept_vector(["alive", "living", "life"])

def remove_projection(v, u):
    return v - np.dot(v, u) * u

def remove_projection_batch(V, u):
    return V - np.outer(np.dot(V, u), u)

from sklearn.metrics.pairwise import cosine_similarity

def concept_cosine_similarity(v1, v2, concept_vector=None):
    
    if concept_vector is not None:
        v1 = remove_projection_batch(v1, concept_vector)
        v2 = remove_projection_batch(v2, concept_vector)

    return cosine_similarity(v1, v2)

# %%
sent1 = "I am alive"
sent2 = "I am dead"

doc_embs1 = encode_texts(sent1)
doc_embs2 = encode_texts(sent2)

# normal cosine similarity
sim_normal = cosine_similarity(doc_embs1, doc_embs2)[0][0]

# concept-modified cosine similarity
sim_modified = concept_cosine_similarity(
    doc_embs1,
    doc_embs2,
    concept_vector=life_concept
)[0][0]

print("normal cosine:", sim_normal)
print("concept adjusted cosine:", sim_modified)
# Out:
# normal cosine: 0.6230484
# concept adjusted cosine: 0.5508945

# %%
sent1 = "m w"
sent2 = "w"

doc_embs1 = encode_texts(sent1)
doc_embs2 = encode_texts(sent2)

# Compute cosine similarities between query and all documents
sims = cosine_similarity(doc_embs1, doc_embs2)[0]
sims
doc_embs1.shape, doc_embs2.shape
doc_embs1
# Out:
# array([[-2.36448366e-02, -3.63496020e-02,  1.64196119e-02,
#          9.29935277e-03, -1.14652617e-02,  5.00973389e-02,
#         -8.31032619e-02,  1.24702055e-03, -9.58361570e-03,
#          5.77908941e-03,  1.25655122e-02, -9.95258521e-03,
#          3.50806452e-02, -1.61630251e-02,  4.13774922e-02,
#         -8.57478566e-03, -2.67889332e-02,  8.00009165e-03,
#         -1.01228647e-01, -1.56167736e-02, -6.52101114e-02,
#          3.20807174e-02, -1.86769627e-02,  5.68029284e-02,
#          4.03276691e-03, -1.53762577e-02, -4.70276251e-02,
#         -1.93385296e-02,  1.52096264e-02,  2.38528159e-02,
#          3.01668029e-02,  2.17725802e-02,  1.47901420e-02,
#         -1.65675320e-02,  4.42575663e-02, -5.88854076e-04,
#          5.04406961e-03, -3.01154498e-02, -3.05958204e-02,
#         -2.84651257e-02,  2.80315150e-03, -2.31851861e-02,
#          3.45100947e-02,  1.74860004e-02, -4.84534316e-02,
#          1.69677983e-34,  2.67321151e-02, -3.35284770e-02,
#          2.82636397e-02,  7.50299022e-02, -3.01938392e-02,
#          2.31269803e-02, -1.92919821e-02, -2.31560115e-02,
#         -1.13245612e-02, -3.06230187e-02,  1.66416110e-03]], dtype=float32)

# %%
# Cell 2: JSON Loading
file_path = "./data/query_results_v1.json"

try:
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    results = data.get("results", [])
    print(f"Successfully loaded {len(results)} queries from {file_path}.")
except FileNotFoundError:
    print(f"Error: {file_path} not found. Please ensure it is in the same directory.")
    results = []
# Out:
# Successfully loaded 15 queries from ./data/query_results_v1.json.

# %%
# Cell 3: Main Similarity Computation and DataFrame Construction
systems = ["VectorSage", "LitSense2", "PubMed"]
rows = []

print("Computing embeddings and cosine similarities...")

for query_index, entry in enumerate(results):
    query = entry.get("query", "")
    category = entry.get("category", "")
    sources = entry.get("sources", {})

    # Encode the query into a single embedding (shape: (1, d))
    q_emb = encode_texts([query])

    for sys in systems:
        # Get raw documents and original count
        raw_docs = sources.get(sys, [])
        num_docs = len(raw_docs)

        # Filter out empty or whitespace-only strings
        valid_docs = [doc for doc in raw_docs if isinstance(doc, str) and doc.strip()]

        # Fallback for systems that returned no usable documents
        if not valid_docs:
            valid_docs = [""]

        # Encode documents (shape: (k, d))
        doc_embs = encode_texts(valid_docs)

        # Compute cosine similarities between query and all documents
        sims = cosine_similarity(q_emb, doc_embs)[0]

        # Compute max and mean over the system's documents
        cosine_mean = np.sum(sims)/np.array(3)
        if num_docs == 0:
            cosine_mean = 0

        rows.append({
            "query_index": query_index,
            "query": query,
            "category": category,
            "system": sys,
            "num_docs": num_docs,
            "cosine_mean": cosine_mean,
        })

# Create the final DataFrame
df = pd.DataFrame(rows)
print("DataFrame construction complete.")
display(df)
# Out:
# Computing embeddings and cosine similarities...
# DataFrame construction complete.
#     query_index                                              query  \
# 0             0  Linking vaccination uptake behavior with trans...
# 1             0  Linking vaccination uptake behavior with trans...
# 2             0  Linking vaccination uptake behavior with trans...
# 3             1  Are FOLFIRINOX plus Bevacizumab the preferred ...
# 4             1  Are FOLFIRINOX plus Bevacizumab the preferred ...
# 5             1  Are FOLFIRINOX plus Bevacizumab the preferred ...
# 6             2  Methods estimating deaths caused by extreme he...
# 7             2  Methods estimating deaths caused by extreme he...
# 8             2  Methods estimating deaths caused by extreme he...
# 9             3  End-to-end systems that clean hospital data, l...
# 10            3  End-to-end systems that clean hospital data, l...
# 11            3  End-to-end systems that clean hospital data, l...
# 12            4  Diagnostic AI designed to work in clinics with...
# 13            4  Diagnostic AI designed to work in clinics with...
# 14            4  Diagnostic AI designed to work in clinics with...
# 15            5  Models maintaining diagnostic accuracy when ap...
# 16            5  Models maintaining diagnostic accuracy when ap...
# 17            5  Models maintaining diagnostic accuracy when ap...
# 18            6  Interactive outbreak dashboards allowing polic...
# 19            6  Interactive outbreak dashboards allowing polic...
# 20            6  Interactive outbreak dashboards allowing polic...
# 21            7  Public-health simulations evaluating intervent...
# 22            7  Public-health simulations evaluating intervent...
# 23            7  Public-health simulations evaluating intervent...
# 24            8  Computational approaches identifying optimal v...
# 25            8  Computational approaches identifying optimal v...
# 26            8  Computational approaches identifying optimal v...
# 27            9  People whose immune system gradually destroys ...
# 28            9  People whose immune system gradually destroys ...
# 29            9  People whose immune system gradually destroys ...
# 30           10  What makes some patients with the same tumor t...
# 31           10  What makes some patients with the same tumor t...
# 32           10  What makes some patients with the same tumor t...
# 33           11  Why do patients who initially respond to a tar...
# 34           11  Why do patients who initially respond to a tar...
# 35           11  Why do patients who initially respond to a tar...
# 36           12  How does having excess fat tissue alter the wa...
# 37           12  How does having excess fat tissue alter the wa...
# 38           12  How does having excess fat tissue alter the wa...
# 39           13
# 40           13
# 41           13
# 42           14
# 43           14
# 44           14
#
#                                      category      system  num_docs  \
# 0                   Multi-Hop Concept Queries  VectorSage         3
# 1                   Multi-Hop Concept Queries   LitSense2         3
# 2                   Multi-Hop Concept Queries      PubMed         0
# 3                    Clinical Treatment Query  VectorSage         3
# 4                    Clinical Treatment Query   LitSense2         2
# 5                    Clinical Treatment Query      PubMed         0
# 6           Lay-Language Clinical Description  VectorSage         3
# 7           Lay-Language Clinical Description   LitSense2         3
# 8           Lay-Language Clinical Description      PubMed         3
# 9                 Pipeline / Workflow Queries  VectorSage         3
# 10                Pipeline / Workflow Queries   LitSense2         3
# 11                Pipeline / Workflow Queries      PubMed         0
# 12       Resource-Constrained Setting Queries  VectorSage         3
# 13       Resource-Constrained Setting Queries   LitSense2         3
# 14       Resource-Constrained Setting Queries      PubMed         0
# 15        Robustness / Generalization Queries  VectorSage         3
# 16        Robustness / Generalization Queries   LitSense2         3
# 17        Robustness / Generalization Queries      PubMed         2
# 18               Human–AI Interaction Queries  VectorSage         3
# 19               Human–AI Interaction Queries   LitSense2         3
# 20               Human–AI Interaction Queries      PubMed         0
# 21  Ethical / Fairness-Aware Modeling Queries  VectorSage         3
# 22  Ethical / Fairness-Aware Modeling Queries   LitSense2         3
# 23  Ethical / Fairness-Aware Modeling Queries      PubMed         2
# 24          Intervention Optimization Queries  VectorSage         3
# 25          Intervention Optimization Queries   LitSense2         3
# 26          Intervention Optimization Queries      PubMed         0
# 27                            Terminology Gap  VectorSage         3
# 28                            Terminology Gap   LitSense2         3
# 29                            Terminology Gap      PubMed         0
# 30                            Terminology Gap  VectorSage         3
# 31                            Terminology Gap   LitSense2         3
# 32                            Terminology Gap      PubMed         0
# 33                            Terminology Gap  VectorSage         3
# 34                            Terminology Gap   LitSense2         3
# 35                            Terminology Gap      PubMed         0
# 36                            Terminology Gap  VectorSage         3
# 37                            Terminology Gap   LitSense2         3
# 38                            Terminology Gap      PubMed         0
# 39                                             VectorSage         3
# 40                                              LitSense2         3
# 41                                                 PubMed         0
# 42                                             VectorSage         3
# 43                                              LitSense2         3
# 44                                                 PubMed         0
#
#     cosine_mean
# 0      0.651821
# 1      0.483741
# 2      0.000000
# 3      0.792963
# 4      0.459582
# 5      0.000000
# 6      0.831096
# 7      0.697893
# 8      0.504391
# 9      0.537896
# 10     0.219396
# 11     0.000000
# 12     0.402592
# 13     0.360502
# 14     0.000000
# 15     0.506723
# 16     0.237401
# 17     0.109226
# 18     0.661137
# 19     0.318608
# 20     0.000000
# 21     0.501181
# 22     0.357529
# 23     0.258129
# 24     0.756093
# 25     0.585788
# 26     0.000000
# 27     0.618277
# 28     0.100621
# 29     0.000000
# 30     0.605150
# 31     0.288653
# 32     0.000000
# 33     0.332972
# 34     0.163561
# 35     0.000000
# 36     0.432745
# 37     0.313188
# 38     0.000000
# 39     0.333333
# 40     0.333333
# 41     0.000000
# 42     0.333333
# 43     0.333333
# 44     0.000000

# %%
# Cell 4: Pivot Tables

# Pivot for Mean Cosine Similarity
pivot_mean = df.pivot(
    index=["query_index", "category"],
    columns="system",
    values="cosine_mean",
)


print("\n--- Pivot Table: Mean Cosine Similarity ---")
display(pivot_mean)
# Out:
# --- Pivot Table: Mean Cosine Similarity ---
# system                                                 LitSense2    PubMed  \
# query_index category
# 0           Multi-Hop Concept Queries                   0.483741  0.000000
# 1           Clinical Treatment Query                    0.459582  0.000000
# 2           Lay-Language Clinical Description           0.697893  0.504391
# 3           Pipeline / Workflow Queries                 0.219396  0.000000
# 4           Resource-Constrained Setting Queries        0.360502  0.000000
# 5           Robustness / Generalization Queries         0.237401  0.109226
# 6           Human–AI Interaction Queries                0.318608  0.000000
# 7           Ethical / Fairness-Aware Modeling Queries   0.357529  0.258129
# 8           Intervention Optimization Queries           0.585788  0.000000
# 9           Terminology Gap                             0.100621  0.000000
# 10          Terminology Gap                             0.288653  0.000000
# 11          Terminology Gap                             0.163561  0.000000
# 12          Terminology Gap                             0.313188  0.000000
# 13                                                      0.333333  0.000000
# 14                                                      0.333333  0.000000
#
# system                                                 VectorSage
# query_index category
# 0           Multi-Hop Concept Queries                    0.651821
# 1           Clinical Treatment Query                     0.792963
# 2           Lay-Language Clinical Description            0.831096
# 3           Pipeline / Workflow Queries                  0.537896
# 4           Resource-Constrained Setting Queries         0.402592
# 5           Robustness / Generalization Queries          0.506723
# 6           Human–AI Interaction Queries                 0.661137
# 7           Ethical / Fairness-Aware Modeling Queries    0.501181
# 8           Intervention Optimization Queries            0.756093
# 9           Terminology Gap                              0.618277
# 10          Terminology Gap                              0.605150
# 11          Terminology Gap                              0.332972
# 12          Terminology Gap                              0.432745
# 13                                                       0.333333
# 14                                                       0.333333

# %%
# Visualization: mean cosine similarity per category and system
import matplotlib.pyplot as plt
import seaborn as sns

# Use pivot_mean if available; if not, recompute from df
try:
    pivot_to_plot = pivot_mean.copy()
except NameError:
    pivot_to_plot = df.pivot(
        index=["query_index", "category"],
        columns="system",
        values="cosine_mean",
    )

# Flatten index so we can use category labels on x-axis
pivot_plot = pivot_to_plot.reset_index()

# Get seaborn deep palette
deep_palette = sns.color_palette("deep")

fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(len(pivot_plot))
width = 0.25

ax.bar(x - width, pivot_plot["VectorSage"], width, label="VectorSage", color=deep_palette[0])
ax.bar(x,         pivot_plot["LitSense2"],  width, label="LitSense2", color=deep_palette[1])
ax.bar(x + width, pivot_plot["PubMed"],     width, label="PubMed", color=deep_palette[2])

ax.set_xticks(x)
ax.set_xticklabels(pivot_plot["category"], rotation=25, ha="right")
ax.set_ylabel("Mean cosine similarity")
ax.set_title("")
ax.legend()

# Remove spines (box)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
#ax.tick_params(axis='both', which='major', width=2, length=6)

# Increase tick line thickness (major ticks)
ax.tick_params(axis='both', which='major', width=2, length=6)
# Increase minor tick line thickness
ax.tick_params(axis='both', which='minor', width=3, length=4)

plt.tight_layout()
plt.savefig('./Figures/mean_cosine_similarity_per_category_v1.tiff', dpi=300, bbox_inches='tight')
plt.savefig('./Figures/mean_cosine_similarity_per_category_v1.svg', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Visualization: overall mean cosine similarity per system
import matplotlib.pyplot as plt
import seaborn as sns

# Compute overall mean cosine similarity per system
mean_per_system = df.groupby("system")["cosine_mean"].mean().reindex(["VectorSage", "LitSense2", "PubMed"])

# Get seaborn deep palette
deep_palette = sns.color_palette("deep")

fig, ax = plt.subplots(figsize=(6, 4))

ax.bar(mean_per_system.index, mean_per_system.values, color=[deep_palette[0], deep_palette[1], deep_palette[2]])
ax.set_ylabel("Mean cosine similarity")
ax.set_title("")

# Remove spines (box)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
#ax.tick_params(axis='both', which='major', width=2, length=6)

# Increase tick line thickness (major ticks)
ax.tick_params(axis='both', which='major', width=2, length=6)
# Increase minor tick line thickness
ax.tick_params(axis='both', which='minor', width=3, length=4)

plt.tight_layout()
plt.savefig('./Figures/overall_mean_cosine_similarity_per_system_v1.tiff', dpi=300, bbox_inches='tight')
plt.savefig('./Figures/overall_mean_cosine_similarity_per_system_v1.svg', dpi=300, bbox_inches='tight')
plt.show()




mean_per_system
# Out:
# system
# VectorSage    0.553154
# LitSense2     0.350209
# PubMed        0.058116
# Name: cosine_mean, dtype: float64

# %%
# Per-document similarities: one row per query–system–document (no averaging)

rows_docs = []
systems = ["VectorSage", "LitSense2", "PubMed"]

print("Computing per-document similarities...")

for query_index, entry in enumerate(results):
    query = entry.get("query", "")
    category = entry.get("category", "")
    sources = entry.get("sources", {})

    if not query:
        continue

    # Encode query once per entry
    q_emb = encode_texts([query])  # shape: (1, d)

    for sys in systems:
        docs_raw = sources.get(sys, []) or []

        if not docs_raw:
            # Represent a "no result" as a single empty doc so it appears explicitly
            docs_raw = [""]

        # Use empty string as-is for embedding so similarity stays low
        docs_for_embed = [doc if isinstance(doc, str) else "" for doc in docs_raw]

        doc_embs = encode_texts(docs_for_embed)  # shape: (k, d)
        sims = cosine_similarity(q_emb, doc_embs)[0]  # shape: (k,)

        for doc_idx, (doc_text, sim) in enumerate(zip(docs_raw, sims)):
            rows_docs.append({
                "query_index": query_index,
                "query": query,
                "category": category,
                "system": sys,
                "doc_index": doc_idx,
                "title": doc_text,
                "cosine": float(sim),
            })

df_docs = pd.DataFrame(rows_docs)
print("Per-document DataFrame shape:", df_docs.shape)
display(df_docs.head())
# Out:
# Computing per-document similarities...
# Per-document DataFrame shape: (94, 7)
#    query_index                                              query  \
# 0            0  Linking vaccination uptake behavior with trans...
# 1            0  Linking vaccination uptake behavior with trans...
# 2            0  Linking vaccination uptake behavior with trans...
# 3            0  Linking vaccination uptake behavior with trans...
# 4            0  Linking vaccination uptake behavior with trans...
#
#                     category      system  doc_index  \
# 0  Multi-Hop Concept Queries  VectorSage          0
# 1  Multi-Hop Concept Queries  VectorSage          1
# 2  Multi-Hop Concept Queries  VectorSage          2
# 3  Multi-Hop Concept Queries   LitSense2          0
# 4  Multi-Hop Concept Queries   LitSense2          1
#
#                                                title    cosine
# 0  Critical dynamics in population vaccinating be...  0.764468
# 1  Impact of Public Health Responses During a Mea...  0.667522
# 2  Complex social contagion makes networks more v...  0.523475
# 3  Existence and stability of equilibria in infec...  0.557367
# 4  Public health measures during an anticipated i...  0.492204

# %%
# Per-document similarities: one row per query–system–document (no averaging)

rows_docs = []
systems = ["VectorSage", "LitSense2", "PubMed"]

print("Computing per-document similarities...")

for query_index, entry in enumerate(results):
    query = entry.get("query", "")
    category = entry.get("category", "")
    sources = entry.get("sources", {})

    if not query:
        continue

    # Encode query once per entry
    q_emb = encode_texts([query])  # shape: (1, d)

    for sys in systems:
        docs_raw = sources.get(sys, []) or []

        if not docs_raw:
            # Represent a "no result" as a single empty doc so it appears explicitly
            docs_raw = [""]

        # Use empty string as-is for embedding so similarity stays low
        docs_for_embed = [doc if isinstance(doc, str) else "" for doc in docs_raw]

        doc_embs = encode_texts(docs_for_embed)  # shape: (k, d)
        sims = cosine_similarity(q_emb, doc_embs)[0]  # shape: (k,)

        for doc_idx, (doc_text, sim) in enumerate(zip(docs_raw, sims)):
            rows_docs.append({
                "query_index": query_index,
                "query": query,
                "category": category,
                "system": sys,
                "doc_index": doc_idx,
                "title": doc_text,
                "cosine": float(sim),
            })

df_docs = pd.DataFrame(rows_docs)
print("Per-document DataFrame shape:", df_docs.shape)
display(df_docs.head())

# Per-document labeling and JSON export + visualization

def success_label_doc(score: float) -> str:
    if score >= 0.70:
        return "Relevant"
    elif score >= 0.50:
        return "Partially relevant"
    elif score >= 0.25:
        return "Weakly relevant"
    else:
        return "Irrelevant"

if "cosine" not in df_docs.columns:
    raise ValueError("df_docs must contain a 'cosine' column with per-document similarities.")

# Label each individual document
df_docs_labeled = df_docs.copy()
df_docs_labeled["success_label"] = df_docs_labeled["cosine"].apply(success_label_doc)

display(df_docs_labeled.head())

# Build a JSON structure with labels per query, per system, per document
labeled_doc_results = []
for q_idx, group_q in df_docs_labeled.groupby("query_index"):
    entry = {
        "query_index": int(q_idx),
        "query": group_q["query"].iloc[0],
        "category": group_q["category"].iloc[0],
        "systems": {},
    }
    for sys, group_sys in group_q.groupby("system"):
        docs_list = []
        for _, row in group_sys.sort_values("doc_index").iterrows():
            docs_list.append({
                "doc_index": int(row["doc_index"]),
                "title": row["title"],
                "cosine": float(row["cosine"]),
                "label": row["success_label"],
            })
        entry["systems"][sys] = docs_list
    labeled_doc_results.append(entry)

output_docs_path = "./data/query_results_docs_scored_v1.json"
with open(output_docs_path, "w", encoding="utf-8") as f:
    json.dump({"results": labeled_doc_results}, f, indent=2, ensure_ascii=False)

print(f"Wrote per-document labeled results to {output_docs_path}")

# Visualization: per-document label distribution per system (percentages)
import seaborn as sns

label_counts_docs = (
    df_docs_labeled
    .groupby(["system", "success_label"])
    .size()
    .reset_index(name="count")
)

total_per_system_docs = label_counts_docs.groupby("system")["count"].sum()

label_order = [
    "Irrelevant",
    "Weakly relevant",
    "Partially relevant",
    "Relevant"
]

# Get seaborn deep palette
deep_palette = sns.color_palette("deep")
label_colors = {
    "Relevant": deep_palette[2],
    "Partially relevant": deep_palette[0],
    "Weakly relevant": deep_palette[1],
    "Irrelevant": deep_palette[3]
}

systems_docs = sorted(df_docs_labeled["system"].unique())

fig, ax = plt.subplots(figsize=(8, 5))

bottom = np.zeros(len(systems_docs))

for label in label_order:
    counts = []
    percents = []
    for i, sys in enumerate(systems_docs):
        row = label_counts_docs[(label_counts_docs["system"] == sys) & (label_counts_docs["success_label"] == label)]
        c = int(row["count"].iloc[0]) if not row.empty else 0
        counts.append(c)
        total = int(total_per_system_docs.loc[sys]) if sys in total_per_system_docs else 0
        perc = (c / total * 100) if total > 0 else 0.0
        percents.append(perc)

    counts = np.array(counts)
    bars = ax.bar(systems_docs, counts, bottom=bottom, label=label, color=label_colors[label])

    for i, bar in enumerate(bars):
        if counts[i] == 0:
            continue
        height = bar.get_height()
        y = bar.get_y() + height / 2
        ax.text(bar.get_x() + bar.get_width() / 2, y, f"{percents[i]:.0f}%",
                ha="center", va="center", fontsize=9, color="white")

    bottom += counts

ax.set_ylabel("Number of documents")
ax.set_title("")
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1], title="Label")

# Remove spines (box)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
#ax.tick_params(axis='both', which='major', width=2, length=6)

# Increase tick line thickness
ax.tick_params(axis='both', which='major', width=2, length=6)

plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('./Figures/per_document_relevance_label_distribution_v1.tiff', dpi=300, bbox_inches='tight')
plt.savefig('./Figures/per_document_relevance_label_distribution_v1.svg', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Computing per-document similarities...
# Per-document DataFrame shape: (94, 7)
#    query_index                                              query  \
# 0            0  Linking vaccination uptake behavior with trans...
# 1            0  Linking vaccination uptake behavior with trans...
# 2            0  Linking vaccination uptake behavior with trans...
# 3            0  Linking vaccination uptake behavior with trans...
# 4            0  Linking vaccination uptake behavior with trans...
#
#                     category      system  doc_index  \
# 0  Multi-Hop Concept Queries  VectorSage          0
# 1  Multi-Hop Concept Queries  VectorSage          1
# 2  Multi-Hop Concept Queries  VectorSage          2
# 3  Multi-Hop Concept Queries   LitSense2          0
# 4  Multi-Hop Concept Queries   LitSense2          1
#
#                                                title    cosine
# 0  Critical dynamics in population vaccinating be...  0.764468
# 1  Impact of Public Health Responses During a Mea...  0.667522
# 2  Complex social contagion makes networks more v...  0.523475
# 3  Existence and stability of equilibria in infec...  0.557367
# 4  Public health measures during an anticipated i...  0.492204
#    query_index                                              query  \
# 0            0  Linking vaccination uptake behavior with trans...
# 1            0  Linking vaccination uptake behavior with trans...
# 2            0  Linking vaccination uptake behavior with trans...
# 3            0  Linking vaccination uptake behavior with trans...
# 4            0  Linking vaccination uptake behavior with trans...
#
#                     category      system  doc_index  \
# 0  Multi-Hop Concept Queries  VectorSage          0
# 1  Multi-Hop Concept Queries  VectorSage          1
# 2  Multi-Hop Concept Queries  VectorSage          2
# 3  Multi-Hop Concept Queries   LitSense2          0
# 4  Multi-Hop Concept Queries   LitSense2          1
#
#                                                title    cosine  \
# 0  Critical dynamics in population vaccinating be...  0.764468
# 1  Impact of Public Health Responses During a Mea...  0.667522
# 2  Complex social contagion makes networks more v...  0.523475
# 3  Existence and stability of equilibria in infec...  0.557367
# 4  Public health measures during an anticipated i...  0.492204
#
#         success_label
# 0            Relevant
# 1  Partially relevant
# 2  Partially relevant
# 3  Partially relevant
# 4     Weakly relevant
# Wrote per-document labeled results to ./data/query_results_docs_scored_v1.json

# %%
# Combined visualization: first figure on top, two others below side-by-side
import matplotlib.pyplot as plt
import seaborn as sns


system_display = {
    "VectorSage": "VectorSage",
    "LitSense2": "LitSense2",
    "PubMed": "PubMed",
        "VectorSage": "VectorSage",
}
# Get seaborn deep palette
deep_palette = sns.color_palette("deep")

# Create figure with GridSpec: 2 rows, 2 columns
fig = plt.figure(figsize=(14, 11))
gs = fig.add_gridspec(2, 2, hspace=0.5, wspace=0.3)

# Top plot spans both columns
ax1 = fig.add_subplot(gs[0, :])

# Bottom plots: left and right
ax2 = fig.add_subplot(gs[1, 0])
ax3 = fig.add_subplot(gs[1, 1])

# --- TOP PLOT: Mean cosine similarity per category and system ---
pivot_plot = pivot_mean.reset_index()

x = np.arange(len(pivot_plot))
width = 0.25
print(pivot_plot)
ax1.bar(x - width, pivot_plot["VectorSage"], width, label="VectorSage", color=deep_palette[0])
ax1.bar(x,         pivot_plot["LitSense2"],  width, label="LitSense2", color=deep_palette[1])
ax1.bar(x + width, pivot_plot["PubMed"],     width, label="PubMed", color=deep_palette[2])

ax1.set_xticks(x)
ax1.set_xticklabels(pivot_plot["category"], rotation=25, ha="right", fontsize=9)
ax1.set_ylabel("Mean cosine similarity")
ax1.set_title("")
ax1.legend()

# Remove spines (box)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_linewidth(2)
ax1.spines['bottom'].set_linewidth(2)

# Increase tick line thickness (major ticks)
ax1.tick_params(axis='both', which='major', width=2, length=6)
ax1.tick_params(axis='both', which='minor', width=3, length=4)

ax1.hlines(y=0.5, xmin=-0.6, xmax= 14.0, colors='red', linestyles='dashed', linewidth=1)

# Add (A) label
ax1.text(-0.08, 1.05, '(A)', transform=ax1.transAxes, fontsize=14, fontweight='bold', va='top')

# --- BOTTOM LEFT PLOT: Overall mean cosine similarity per system ---
mean_per_system = df.groupby("system")["cosine_mean"].mean().reindex(["VectorSage", "LitSense2", "PubMed"])
display_index = [system_display[s] for s in mean_per_system.index]

bar_width = 0.8
ax2.bar(display_index, mean_per_system.values, width=bar_width, color=[deep_palette[0], deep_palette[1], deep_palette[2]])
ax2.set_ylabel("Mean cosine similarity")
ax2.set_title("")
ax2.set_xlim(-0.5, 2.5)

# Remove spines (box)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['left'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)

# Increase tick line thickness (major ticks)
ax2.tick_params(axis='both', which='major', width=2, length=6)
ax2.tick_params(axis='both', which='minor', width=3, length=4)

# Add (B) label
ax2.text(-0.15, 1.05, '(B)', transform=ax2.transAxes, fontsize=14, fontweight='bold', va='top')
ax2.annotate(f"{mean_per_system['VectorSage']:.3f}", xy=(0, mean_per_system['VectorSage']), xytext=(-0.1, mean_per_system['VectorSage'] + 0.01),
                fontsize=10, color='black')
ax2.annotate(f"{mean_per_system['LitSense2']:.3f}", xy=(1, mean_per_system['LitSense2']), xytext=(0.9, mean_per_system['LitSense2'] + 0.01),
                fontsize=10, color='black')
ax2.annotate(f"{mean_per_system['PubMed']:.3f}", xy=(2, mean_per_system['PubMed']), xytext=(1.9, mean_per_system['PubMed'] + 0.01),
                fontsize=10, color='black')
# --- BOTTOM RIGHT PLOT: Per-document label distribution ---
label_counts_docs = (
    df_docs_labeled
    .groupby(["system", "success_label"])
    .size()
    .reset_index(name="count")
)

total_per_system_docs = label_counts_docs.groupby("system")["count"].sum()

label_order = [
    "Irrelevant",
    "Weakly relevant",
    "Partially relevant",
    "Relevant"
]

label_colors = {
    "Relevant": deep_palette[2],
    "Partially relevant": deep_palette[0],
    "Weakly relevant": deep_palette[1],
    "Irrelevant": deep_palette[3]
}

# systems_docs = sorted(df_docs_labeled["system"].unique())
systems_docs = systems

bottom = np.zeros(len(systems_docs))

for label in label_order:
    counts = []
    percents = []
    for i, sys in enumerate(systems_docs):
        row = label_counts_docs[(label_counts_docs["system"] == sys) & (label_counts_docs["success_label"] == label)]
        c = int(row["count"].iloc[0]) if not row.empty else 0
        counts.append(c)
        total = int(total_per_system_docs.loc[sys]) if sys in total_per_system_docs else 0
        perc = (c / total * 100) if total > 0 else 0.0
        percents.append(perc)


    counts = np.array(counts)
    display_systems = [system_display[s] for s in systems_docs]



    bars = ax3.bar(display_systems, counts, width=bar_width, bottom=bottom, label=label, color=label_colors[label])

    for i, bar in enumerate(bars):
        if counts[i] == 0:
            continue
        height = bar.get_height()
        y = bar.get_y() + height / 2
        ax3.text(bar.get_x() + bar.get_width() / 2, y, f"{percents[i]:.0f}%",
                ha="center", va="center", fontsize=9, color="white")

    bottom += counts

ax3.set_ylabel("Number of documents")
ax3.set_title("")
handles, labels = ax3.get_legend_handles_labels()
print(labels)
ax3.legend(handles[::-1], labels[::-1], title="Label", fontsize=8)

# Remove spines (box)
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.spines['left'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)

# Increase tick line thickness
ax3.tick_params(axis='both', which='major', width=2, length=6)

# Add (C) label
ax3.text(-0.15, 1.05, '(C)', transform=ax3.transAxes, fontsize=14, fontweight='bold', va='top')



plt.savefig('./Figures/combined_cosine_similarity_figures_v1.tiff', dpi=300, bbox_inches='tight')
plt.savefig('./Figures/combined_cosine_similarity_figures_v1.svg', bbox_inches='tight')
plt.show()
# Out:
# system  query_index                                   category  LitSense2  \
# 0                 0                  Multi-Hop Concept Queries   0.483741
# 1                 1                   Clinical Treatment Query   0.459582
# 2                 2          Lay-Language Clinical Description   0.697893
# 3                 3                Pipeline / Workflow Queries   0.219396
# 4                 4       Resource-Constrained Setting Queries   0.360502
# 5                 5        Robustness / Generalization Queries   0.237401
# 6                 6               Human–AI Interaction Queries   0.318608
# 7                 7  Ethical / Fairness-Aware Modeling Queries   0.357529
# 8                 8          Intervention Optimization Queries   0.585788
# 9                 9                            Terminology Gap   0.100621
# 10               10                            Terminology Gap   0.288653
# 11               11                            Terminology Gap   0.163561
# 12               12                            Terminology Gap   0.313188
# 13               13                                              0.333333
# 14               14                                              0.333333
#
# system    PubMed  VectorSage
# 0       0.000000    0.651821
# 1       0.000000    0.792963
# 2       0.504391    0.831096
# 3       0.000000    0.537896
# 4       0.000000    0.402592
# 5       0.109226    0.506723
# 6       0.000000    0.661137
# 7       0.258129    0.501181
# 8       0.000000    0.756093
# 9       0.000000    0.618277
# 10      0.000000    0.605150
# 11      0.000000    0.332972
# 12      0.000000    0.432745
# 13      0.000000    0.333333
# 14      0.000000    0.333333
# ['Irrelevant', 'Weakly relevant', 'Partially relevant', 'Relevant']
