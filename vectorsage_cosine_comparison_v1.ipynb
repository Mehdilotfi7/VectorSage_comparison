# %%
# Cell 1: Imports, Model Loading, and Explicit Encoding Function
import json
import torch
import torch.nn.functional as F
import pandas as pd
import numpy as np
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity

# Define the model checkpoint
MODEL_NAME = "sentence-transformers/all-mpnet-base-v2"

# Load tokenizer and model from Hugging Face
print(f"Loading tokenizer and model: {MODEL_NAME}...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)
print("Model loaded successfully.")
# Out:
# Loading tokenizer and model: sentence-transformers/all-mpnet-base-v2...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded successfully.

# %%
def encode_texts(texts):
    """Encodes a list of strings into L2-normalized dense embeddings
    using explicitly implemented mean pooling and attention masking.
    """
    # Ensure we always have a list
    if isinstance(texts, str):
        texts = [texts]

    # Tokenize input texts
    encoded_input = tokenizer(
        texts,
        padding=True,
        truncation=True,
        return_tensors="pt",
    )

    # Compute token embeddings
    with torch.no_grad():
        model_output = model(**encoded_input)

    # Mean Pooling Logic
    token_embeddings = model_output[0]
    attention_mask = encoded_input["attention_mask"]
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()

    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    pooled_embeddings = sum_embeddings / sum_mask

    # L2 Normalization
    normalized_embeddings = F.normalize(pooled_embeddings, p=2, dim=1)

    return normalized_embeddings.numpy()

# %%
sent1 = "I am alive"
sent2 = "I am dead"


doc_embs1 = encode_texts(sent1)
doc_embs2 = encode_texts(sent2)
doc_embs3 = doc_embs1 - doc_embs2

sim_normal1 = cosine_similarity(doc_embs1, doc_embs2)[0]
sim_normal2 = cosine_similarity(doc_embs1, doc_embs3)[0]

sim_normal1, sim_normal2
# Out:
# (array([0.6230483], dtype=float32), array([0.53471506], dtype=float32))

# %%
import numpy as np

def build_concept_vector(words):
    embs = encode_texts(words)
    u = embs.mean(axis=0)
    u = u / np.linalg.norm(u)
    return u

life_concept = build_concept_vector(["alive", "living", "life"])

def remove_projection(v, u):
    return v - np.dot(v, u) * u

def remove_projection_batch(V, u):
    return V - np.outer(np.dot(V, u), u)

from sklearn.metrics.pairwise import cosine_similarity

def concept_cosine_similarity(v1, v2, concept_vector=None):
    
    if concept_vector is not None:
        v1 = remove_projection_batch(v1, concept_vector)
        v2 = remove_projection_batch(v2, concept_vector)

    return cosine_similarity(v1, v2)

# %%
sent1 = "I am alive"
sent2 = "I am dead"

doc_embs1 = encode_texts(sent1)
doc_embs2 = encode_texts(sent2)

# normal cosine similarity
sim_normal = cosine_similarity(doc_embs1, doc_embs2)[0][0]

# concept-modified cosine similarity
sim_modified = concept_cosine_similarity(
    doc_embs1,
    doc_embs2,
    concept_vector=life_concept
)[0][0]

print("normal cosine:", sim_normal)
print("concept adjusted cosine:", sim_modified)
# Out:
# normal cosine: 0.6230483
# concept adjusted cosine: 0.54952395

# %%
sent1 = "m w"
sent2 = "w"

doc_embs1 = encode_texts(sent1)
doc_embs2 = encode_texts(sent2)

# Compute cosine similarities between query and all documents
sims = cosine_similarity(doc_embs1, doc_embs2)[0]
sims
doc_embs1.shape, doc_embs2.shape
doc_embs1
# Out:
# array([[-6.40519112e-02, -9.84680727e-02,  4.44793701e-02,
#          2.51911785e-02, -3.10584456e-02,  1.35709554e-01,
#         -2.25119874e-01,  3.37807555e-03, -2.59612221e-02,
#          1.56550761e-02,  3.40389349e-02, -2.69607306e-02,
#          9.50305685e-02, -4.37842980e-02,  1.12088203e-01,
#         -2.32283864e-02, -7.25690052e-02,  2.16715876e-02,
#         -2.74220049e-01, -4.23045494e-02, -1.76648811e-01,
#          3.65983918e-02, -1.07250847e-01, -5.71767613e-02,
#          3.98452394e-02, -8.44839662e-02, -1.56366751e-02,
#          5.79800606e-02, -6.39733076e-02,  1.16333622e-03,
#         -3.11137810e-02, -1.59181133e-02, -1.42740682e-02,
#          5.54957390e-02,  5.65910204e-06, -1.44352779e-01,
#          5.28168902e-02, -1.05110675e-01,  1.03067711e-01,
#         -7.33303726e-02, -1.40823931e-01, -4.18388210e-02,
#         -4.60962430e-02,  9.56176519e-02,  1.79857872e-02,
#         -4.79623228e-02,  9.09248739e-02,  3.11681610e-02,
#         -1.35573313e-01,  6.24738820e-03,  2.31622234e-02,
#         -8.62143748e-03, -1.99463338e-01, -5.90831935e-02,
#          1.76204547e-01, -1.17884967e-02,  1.71092510e-01,
#          1.10205725e-01, -5.96263334e-02, -5.44830924e-03,
#         -3.40541489e-02,  9.19575691e-02, -1.88316941e-01,
#          1.18725643e-01,  1.48732111e-01,  6.60374910e-02,
#          2.03330860e-01, -3.78216244e-02,  1.91574823e-02,
#          5.64610884e-02,  2.04143345e-01,  9.71720926e-03,
#          1.70929790e-01,  1.76278621e-01, -1.85806118e-02,
#         -6.84230700e-02, -9.35730413e-02,  1.03056438e-01,
#         -4.73296605e-02, -6.74318299e-02, -2.16929704e-01,
#          2.03669518e-01,  1.57115757e-01,  1.02881722e-01,
#         -6.52764067e-02,  2.54031479e-01, -2.65094992e-02,
#          2.72216238e-02,  2.17509139e-02,  5.84910624e-02,
#         -2.72482894e-02, -5.67199811e-02, -5.58146834e-02,
#          7.21904784e-02,  5.54370545e-02,  2.02785805e-02,
#         -1.26475602e-01, -5.98538034e-02, -1.36107123e-02,
#         -4.17638838e-01, -1.83373213e-01,  4.01057713e-02,
#          1.62268519e-01,  1.01350039e-01,  2.86583789e-02,
#          1.81206185e-02, -3.60944197e-02, -1.62593752e-01,
#         -4.23626266e-02, -1.94339268e-02, -5.36384545e-02,
#         -2.09167227e-03,  1.34580716e-01,  1.53194647e-02,
#          2.11925954e-02, -6.83394223e-02, -4.05453257e-02,
#          1.19585186e-01,  1.54838804e-02,  5.84440678e-03,
#          6.53167590e-02, -6.48889542e-02, -3.22144702e-02,
#          1.47656158e-01, -7.88283199e-02,  1.58472657e-01,
#         -4.39415127e-02,  4.10491824e-02,  1.46098822e-01,
#          3.76924388e-02, -6.71452731e-02,  3.50104496e-02,
#         -5.43153025e-02, -1.07837811e-01,  1.16856605e-01,
#          2.05690622e-01, -1.61452904e-01,  5.93240485e-02,
#         -1.33917183e-01, -7.27996379e-02, -9.67740417e-02,
#          2.80962996e-02, -3.02383937e-02, -6.56351820e-02,
#          4.44578752e-02,  2.09940970e-02,  4.42968532e-02,
#          9.36676636e-02,  5.65306209e-02, -2.38212235e-02,
#          3.96453217e-02,  4.68446836e-02,  9.54664797e-02,
#          6.27612788e-03,  2.16292471e-01,  3.90800312e-02,
#         -6.38036579e-02, -6.98729903e-02, -5.18042445e-02,
#          1.86214387e-01,  7.33514801e-02,  1.88748129e-02,
#         -4.28882986e-02,  2.12890971e-02, -8.76275152e-02,
#          4.17966917e-02,  1.03295326e-01, -8.76661837e-02,
#         -2.57550050e-02,  9.92403328e-02,  3.06105800e-02,
#          8.92005954e-03, -2.49447431e-02, -2.13223491e-02,
#          1.11753576e-01,  1.42996609e-02,  1.63824886e-01,
#          5.36258966e-02, -2.23240033e-02, -1.55940384e-01,
#         -3.76011766e-02, -3.90306681e-01, -2.27625277e-02,
#          3.97487506e-02, -1.31414697e-01,  2.66085770e-02,
#          5.68374991e-02,  9.88551825e-02, -1.29786715e-01,
#          3.12512228e-03,  8.14484134e-02, -6.28423318e-02,
#         -5.75674474e-02, -5.71225211e-03,  9.05188620e-02,
#         -7.07548410e-02,  5.26619665e-02,  8.60375986e-02,
#          4.48619910e-02,  5.79512827e-02, -1.23197101e-01,
#         -2.30846792e-01, -5.88017069e-02, -6.68967050e-03,
#         -7.80697465e-02, -1.21215641e-01, -1.23720830e-02,
#         -8.54675472e-02, -5.63777983e-03, -3.53541672e-02,
#          9.11613852e-02,  1.01853475e-01,  7.64360055e-02,
#          1.83508061e-02, -5.69590554e-02, -3.89461331e-02,
#          7.96945170e-02,  1.46275964e-02, -6.68075383e-02,
#          4.66143899e-02,  1.28211631e-02, -9.95291620e-02,
#          5.78983538e-02,  4.23749313e-02,  6.06735684e-02,
#          2.24814340e-02,  1.29908279e-01, -3.21311019e-02,
#          7.27285445e-02, -3.59591879e-02,  5.79705201e-02,
#          6.23272248e-02,  5.14219850e-02, -3.55697758e-02,
#          1.83344111e-02,  5.84949031e-02, -4.27573407e-03,
#         -4.92112450e-02, -5.51649649e-03, -1.59549639e-01,
#          1.60866156e-01,  3.87121551e-03, -4.97572497e-03,
#         -9.99754202e-03, -7.99412280e-02,  4.25197408e-02,
#          7.22644851e-02, -1.33848831e-01, -1.06883198e-02,
#         -1.36859426e-02, -1.76871002e-01,  7.84274265e-02,
#          1.41552120e-01, -1.54052973e-01,  1.42555768e-02,
#         -3.03519834e-02, -1.97730869e-01, -4.43054624e-02,
#          7.50255063e-02, -1.10717607e-03,  1.24279127e-01,
#         -1.78791210e-01,  2.17966646e-01, -9.19997245e-02,
#          1.07646137e-02,  1.55296950e-02, -1.68602020e-01,
#          6.58987984e-02,  3.14984769e-02,  4.27771956e-02,
#         -2.16927174e-02,  8.37690085e-02,  1.67819530e-01,
#         -8.60758685e-03,  7.43098706e-02,  2.15883888e-02,
#         -2.00663567e-01,  1.40235499e-02, -1.51514590e-01,
#          2.86854599e-02,  8.59647170e-02,  1.61977991e-01,
#         -5.36347367e-02, -1.51006607e-02, -2.65328214e-03,
#          3.18494393e-03, -1.60309806e-01, -8.42159837e-02,
#         -7.78878629e-02, -1.21081196e-01, -1.65233344e-01,
#         -1.06603310e-01, -1.05481640e-01, -1.91512015e-02,
#          6.68105781e-02, -3.74514163e-02,  1.90652143e-02,
#          7.23048970e-02, -4.73684594e-02,  2.12793037e-01,
#          1.10768571e-01,  1.81767307e-02,  1.06513023e-01,
#         -7.18256086e-02,  1.50603190e-01,  2.84537338e-02,
#         -1.48187978e-02, -5.85771352e-02,  1.23083405e-01,
#          4.29200605e-02,  1.40605969e-02,  3.07910144e-02,
#          6.02175146e-02, -9.51570421e-02,  1.08957835e-01,
#         -1.87198408e-02,  7.59913921e-02,  1.04560452e-02,
#         -9.75141153e-02,  2.37426311e-02,  6.23934828e-02,
#         -2.66929641e-02, -8.36876482e-02, -1.60928100e-01,
#         -3.52625772e-02,  1.18735805e-01, -4.33912650e-02,
#          9.53596383e-02, -9.78802443e-02, -1.23248346e-01,
#         -6.28878828e-03, -8.12325776e-02, -1.63844740e-03,
#          7.19047412e-02,  1.23128638e-01, -3.70325595e-02,
#         -1.31600827e-01, -1.53863892e-01,  5.03522530e-02,
#          1.12059906e-01,  9.02173109e-03,  1.38335973e-01,
#         -8.29249173e-02,  1.22980233e-02, -1.60244435e-01,
#         -3.57573330e-02, -1.66317690e-02,  3.09857354e-02,
#         -1.11165896e-01,  6.37220293e-02,  1.49915159e-01,
#         -2.08720863e-02, -1.82901882e-02, -9.67919603e-02,
#         -7.59113356e-02, -3.92423943e-02, -6.79182038e-02,
#         -4.32055146e-02,  2.47241184e-03, -1.77517459e-01,
#         -2.15929933e-02,  1.75499953e-02,  1.03590991e-02,
#         -2.22524211e-01,  4.00414765e-02, -6.47979751e-02,
#          6.35025054e-02,  8.89614075e-02, -2.58637648e-02,
#         -7.41332322e-02,  2.34728269e-02,  1.19473562e-02,
#          1.51137769e-01,  2.70720888e-02,  7.67214894e-02,
#          9.22059417e-02, -9.00071580e-03,  6.61797673e-02,
#          5.12761250e-02, -4.30859551e-02,  1.05270796e-01,
#          8.63431096e-02, -2.78527662e-02,  1.30181298e-01,
#         -1.51582318e-03, -3.75977457e-02, -7.37331137e-02,
#          4.17599194e-02, -7.57869706e-03, -6.28706440e-02,
#          5.14756404e-02,  3.77265178e-02, -3.61390272e-03,
#          9.97360796e-02,  2.04183683e-02, -3.56217474e-02,
#         -3.20977047e-02,  1.20228797e-01, -3.32136154e-02,
#          1.09429117e-02,  5.88645265e-02,  3.07204723e-01,
#          1.39967278e-02,  6.19813278e-02, -5.04009575e-02,
#         -8.89495984e-02, -7.96407275e-03, -6.78147152e-02,
#         -7.01699555e-02, -2.31770799e-01,  7.27891028e-02,
#         -1.74269136e-02,  2.50748172e-03, -1.64852619e-01,
#         -1.41823115e-02, -1.65355384e-01, -8.65013301e-02,
#         -2.23277509e-01,  8.23143050e-02,  5.67871854e-02,
#         -3.96684557e-02,  1.00955991e-02,  7.59810954e-02,
#         -1.58153251e-01,  1.01845907e-02, -1.37381749e-02,
#          6.75206631e-02, -3.03276405e-02,  1.99098393e-01,
#         -1.81430951e-02, -4.52356488e-02,  1.47752881e-01,
#         -1.15019947e-01, -1.48589443e-02,  2.25641191e-01,
#         -3.24230164e-01, -2.50123180e-02,  1.18355319e-01,
#          6.54694661e-02, -2.57736947e-02,  8.82487558e-03,
#          8.90645534e-02,  1.19694985e-01, -5.01875728e-02,
#          3.84339690e-02, -8.72905031e-02,  3.10990848e-02,
#         -1.72736064e-01, -1.47998273e-01, -8.38621035e-02,
#          8.62507224e-02, -1.62284821e-03,  1.32788539e-01,
#          7.38141611e-02,  1.25373472e-02,  3.11578773e-02,
#          5.16818911e-02, -1.63979754e-01, -6.29518032e-02,
#         -1.77898481e-01,  3.49754155e-01,  7.37443343e-02,
#         -7.72361159e-02,  5.43755628e-02,  1.33821204e-01,
#         -1.55115962e-01, -2.60092616e-02,  3.45590897e-03,
#          1.17453910e-01, -2.87089441e-02, -3.88799235e-04,
#         -7.10661933e-02, -5.07775843e-02, -1.07174309e-03,
#          4.89862487e-02, -2.87807956e-02,  6.50668284e-03,
#          9.33816284e-02,  2.15970278e-01, -7.44797289e-05,
#         -9.06859189e-02, -7.81017393e-02, -6.04600459e-02,
#         -1.27667487e-01, -5.90549260e-02, -1.64530184e-02,
#          9.45238769e-02, -8.62197131e-02,  4.14497703e-02,
#          5.72222620e-02, -3.14735100e-02, -8.75014439e-02,
#         -1.08048350e-01, -1.90248102e-01, -8.11250359e-02,
#         -4.60568853e-02,  8.03781152e-02,  1.18749849e-01,
#         -7.42581934e-02, -7.76595995e-03, -4.14687209e-02,
#          6.29224479e-02, -3.12373862e-02, -3.66261639e-02,
#          1.08717375e-01, -9.94167775e-02,  4.57271971e-02,
#         -4.83153202e-02, -1.49463173e-02, -1.11174174e-02,
#         -7.86325783e-02,  3.21125835e-02, -3.00187021e-02,
#         -1.73016742e-01,  9.43883210e-02,  4.26779360e-01,
#          5.53453676e-02, -2.06809446e-01,  9.25713405e-02,
#          7.85328150e-02,  5.61178550e-02, -9.55819637e-02,
#          4.34169397e-02,  5.10785766e-02,  2.32856303e-01,
#          1.06111199e-01,  7.49612227e-02, -4.32287380e-02,
#         -2.58463621e-02, -1.07618971e-02, -1.08777426e-01,
#         -1.12249792e-01,  2.07536936e-01, -2.24102344e-02,
#         -1.67317435e-01,  1.80721566e-01,  1.96833760e-01,
#          5.95886074e-03, -4.78527620e-02, -5.95720150e-02,
#         -4.85660359e-02, -9.68067441e-03,  1.89965479e-02,
#         -7.28576351e-03,  9.37873945e-02,  7.56456926e-02,
#         -1.76801682e-01,  9.89704505e-02,  5.35333119e-02,
#          5.46122417e-02,  1.86238140e-02,  2.11110525e-02,
#          6.54430017e-02, -2.64178738e-02,  1.47609949e-01,
#         -2.18341846e-32, -3.55278663e-02,  4.09603938e-02,
#          4.83685359e-02, -5.71736060e-02, -1.88825130e-01,
#         -7.19107985e-02,  7.18258694e-02,  5.61161675e-02,
#         -7.99468011e-02, -2.74302810e-02, -2.04732791e-02,
#         -4.35248017e-02,  9.11747515e-02,  3.55599225e-02,
#          1.18101425e-02,  1.56878114e-01,  5.46085536e-02,
#         -5.43329418e-02,  4.55388129e-02, -1.63961738e-01,
#         -8.76186341e-02,  8.22100118e-02, -2.90215164e-02,
#          1.97325304e-01,  2.55665369e-02, -1.47149980e-01,
#         -9.26133171e-02,  9.76195782e-02, -1.81694105e-02,
#          1.24362204e-02,  8.88120942e-03, -3.56174633e-02,
#          4.36413623e-02,  4.57420982e-02, -2.98198350e-02,
#          2.07515135e-01,  3.26306783e-02,  1.13948225e-03,
#         -1.19535409e-01, -9.10100155e-03, -4.98276502e-02,
#         -1.03992477e-01,  1.52609065e-01,  4.03132886e-02,
#          5.00531718e-02, -1.52390078e-01,  8.68561864e-03,
#         -1.35142058e-01, -3.16658802e-02, -6.87299967e-02,
#          1.72710195e-01,  6.82920739e-02,  8.09989125e-03,
#         -1.38383791e-01, -3.67676243e-02, -5.31594753e-02,
#         -4.77661490e-02,  2.46405434e-02, -1.03492774e-01,
#         -6.89367652e-02,  7.09932446e-02,  2.87904833e-02,
#         -2.78618280e-03,  3.74730565e-02,  4.66428921e-02,
#         -3.99396643e-02,  2.32150927e-02,  5.38931638e-02,
#          1.06021166e-01, -5.48871495e-02,  7.57837221e-02,
#          1.67065799e-01,  2.84552407e-02, -5.40920720e-02,
#         -5.56417964e-02, -1.17629871e-01, -4.63694483e-02,
#          2.57267971e-02,  3.02495109e-03,  8.64747912e-02,
#         -1.60829306e-01,  9.73258913e-03,  1.40337646e-01,
#          5.76045997e-02,  3.11491322e-02, -1.28537282e-01,
#         -5.25842160e-02,  1.34650797e-01,  4.67088409e-02,
#          3.64759751e-02, -1.12335896e-02, -1.30210340e-01,
#         -3.09711751e-02, -1.56632625e-02,  3.85615267e-02,
#         -2.86376953e-01,  6.99121803e-02, -3.93934548e-02,
#         -1.30685478e-01, -1.48486689e-01,  2.08872512e-01,
#          1.57169655e-01,  4.90048341e-03, -5.24363481e-03,
#          3.99932228e-02,  1.25729114e-01, -8.63573551e-02,
#         -6.86401576e-02, -1.01557046e-01, -4.64142337e-02,
#         -6.85408860e-02, -5.89439683e-02,  7.99780935e-02,
#         -3.21645774e-02, -2.89815739e-02, -6.70383265e-03,
#         -6.69625588e-03, -1.06662698e-01, -2.09820713e-03,
#         -2.13977814e-01, -1.90054085e-02, -9.68762487e-02,
#         -1.20850764e-01,  7.42513761e-02, -1.32413745e-01,
#          1.36421204e-01,  1.22582331e-01,  2.18373165e-01,
#          1.83596790e-01, -3.84019502e-02, -7.62395635e-02,
#         -7.90448189e-02,  7.30565660e-07,  8.66162777e-02,
#          1.58462916e-02, -8.85279030e-02,  1.15542591e-01,
#         -1.79513358e-02,  7.13657960e-02, -2.88296372e-01,
#          7.87087381e-02, -3.45183983e-02, -4.13142778e-02,
#          1.55207768e-01, -2.02107020e-02,  1.18693434e-01,
#         -1.89220514e-02,  1.17121950e-01,  3.90380248e-02,
#          6.00730851e-02,  4.28766310e-02,  3.95280570e-02,
#         -1.62268713e-01, -1.24689996e-01, -8.55309591e-02,
#          7.83720836e-02,  7.65170995e-03, -1.10317022e-01,
#         -1.18540026e-01,  1.18436351e-01, -1.43866524e-01,
#          2.18175888e-01, -8.96865129e-02,  2.48283505e-01,
#         -7.36017004e-02, -9.39720571e-02, -1.53248683e-01,
#          4.42802534e-02, -1.35334775e-01,  5.39091304e-02,
#          1.87273353e-01,  3.88076976e-02,  2.27954052e-02,
#         -7.73674697e-02,  1.34513572e-01,  3.36329639e-02,
#          8.69040117e-02, -5.05943485e-02,  1.53874442e-01,
#          1.09244324e-02, -4.16530110e-02, -1.27393946e-01,
#         -5.23864776e-02,  4.12016213e-02,  6.46153092e-02,
#          8.17193761e-02,  5.89801222e-02,  4.00652736e-02,
#         -4.48800735e-02,  1.19890094e-01, -1.59515697e-03,
#          1.36639681e-02, -8.15802664e-02, -8.28815475e-02,
#         -7.71096721e-02,  7.59350602e-03, -6.28067553e-02,
#          9.34849903e-02,  4.73681316e-02, -1.31256342e-01,
#          4.59643638e-34,  7.24150911e-02, -9.08258781e-02,
#          7.65638649e-02,  2.03249797e-01, -8.17926154e-02,
#          6.26490787e-02, -5.22603877e-02, -6.27277195e-02,
#         -3.06772999e-02, -8.29552263e-02,  4.50807484e-03]], dtype=float32)

# %%
# Cell 2: JSON Loading
file_path = "./data/query_results_v1.json"

try:
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    results = data.get("results", [])
    print(f"Successfully loaded {len(results)} queries from {file_path}.")
except FileNotFoundError:
    print(f"Error: {file_path} not found. Please ensure it is in the same directory.")
    results = []
# Out:
# Successfully loaded 10 queries from ./data/query_results_v1.json.

# %%
# Cell 3: Main Similarity Computation and DataFrame Construction
systems = ["VectorSage", "LitSense2", "PubMed"]
rows = []

print("Computing embeddings and cosine similarities...")

for query_index, entry in enumerate(results):
    query = entry.get("query", "")
    category = entry.get("category", "")
    sources = entry.get("sources", {})

    # Encode the query into a single embedding (shape: (1, d))
    q_emb = encode_texts([query])

    for sys in systems:
        # Get raw documents and original count
        raw_docs = sources.get(sys, [])
        num_docs = len(raw_docs)

        # Filter out empty or whitespace-only strings
        valid_docs = [doc for doc in raw_docs if isinstance(doc, str) and doc.strip()]

        # Fallback for systems that returned no usable documents
        if not valid_docs:
            valid_docs = [""]

        # Encode documents (shape: (k, d))
        doc_embs = encode_texts(valid_docs)

        # Compute cosine similarities between query and all documents
        sims = cosine_similarity(q_emb, doc_embs)[0]

        # Compute max and mean over the system's documents
        cosine_mean = np.sum(sims)/np.array(3)
        if num_docs == 0:
            cosine_mean = 0

        rows.append({
            "query_index": query_index,
            "query": query,
            "category": category,
            "system": sys,
            "num_docs": num_docs,
            "cosine_mean": cosine_mean,
        })

# Create the final DataFrame
df = pd.DataFrame(rows)
print("DataFrame construction complete.")
display(df)
# Out:
# Computing embeddings and cosine similarities...
# DataFrame construction complete.
#     query_index                                              query  \
# 0             0  Automated systems interpreting chest scans to ...
# 1             0  Automated systems interpreting chest scans to ...
# 2             0  Automated systems interpreting chest scans to ...
# 3             1  Linking vaccination uptake behavior with trans...
# 4             1  Linking vaccination uptake behavior with trans...
# 5             1  Linking vaccination uptake behavior with trans...
# 6             2  Are FOLFIRINOX plus Bevacizumab the preferred ...
# 7             2  Are FOLFIRINOX plus Bevacizumab the preferred ...
# 8             2  Are FOLFIRINOX plus Bevacizumab the preferred ...
# 9             3  Methods estimating deaths caused by extreme he...
# 10            3  Methods estimating deaths caused by extreme he...
# 11            3  Methods estimating deaths caused by extreme he...
# 12            4  End-to-end systems that clean hospital data, l...
# 13            4  End-to-end systems that clean hospital data, l...
# 14            4  End-to-end systems that clean hospital data, l...
# 15            5  Diagnostic AI designed to work in clinics with...
# 16            5  Diagnostic AI designed to work in clinics with...
# 17            5  Diagnostic AI designed to work in clinics with...
# 18            6  Models maintaining diagnostic accuracy when ap...
# 19            6  Models maintaining diagnostic accuracy when ap...
# 20            6  Models maintaining diagnostic accuracy when ap...
# 21            7  Interactive outbreak dashboards allowing polic...
# 22            7  Interactive outbreak dashboards allowing polic...
# 23            7  Interactive outbreak dashboards allowing polic...
# 24            8  Public-health simulations evaluating intervent...
# 25            8  Public-health simulations evaluating intervent...
# 26            8  Public-health simulations evaluating intervent...
# 27            9  Computational approaches identifying optimal v...
# 28            9  Computational approaches identifying optimal v...
# 29            9  Computational approaches identifying optimal v...
#
#                                      category      system  num_docs  \
# 0                             Terminology Gap  VectorSage         3
# 1                             Terminology Gap   LitSense2         3
# 2                             Terminology Gap      PubMed         0
# 3                   Multi-Hop Concept Queries  VectorSage         3
# 4                   Multi-Hop Concept Queries   LitSense2         3
# 5                   Multi-Hop Concept Queries      PubMed         0
# 6                    Clinical Treatment Query  VectorSage         3
# 7                    Clinical Treatment Query   LitSense2         2
# 8                    Clinical Treatment Query      PubMed         0
# 9           Lay-Language Clinical Description  VectorSage         3
# 10          Lay-Language Clinical Description   LitSense2         3
# 11          Lay-Language Clinical Description      PubMed         3
# 12                Pipeline / Workflow Queries  VectorSage         3
# 13                Pipeline / Workflow Queries   LitSense2         3
# 14                Pipeline / Workflow Queries      PubMed         0
# 15       Resource-Constrained Setting Queries  VectorSage         3
# 16       Resource-Constrained Setting Queries   LitSense2         3
# 17       Resource-Constrained Setting Queries      PubMed         0
# 18        Robustness / Generalization Queries  VectorSage         3
# 19        Robustness / Generalization Queries   LitSense2         3
# 20        Robustness / Generalization Queries      PubMed         2
# 21               Human–AI Interaction Queries  VectorSage         3
# 22               Human–AI Interaction Queries   LitSense2         3
# 23               Human–AI Interaction Queries      PubMed         0
# 24  Ethical / Fairness-Aware Modeling Queries  VectorSage         3
# 25  Ethical / Fairness-Aware Modeling Queries   LitSense2         3
# 26  Ethical / Fairness-Aware Modeling Queries      PubMed         2
# 27          Intervention Optimization Queries  VectorSage         3
# 28          Intervention Optimization Queries   LitSense2         3
# 29          Intervention Optimization Queries      PubMed         0
#
#     cosine_mean
# 0      0.470327
# 1      0.462095
# 2      0.000000
# 3      0.651821
# 4      0.483741
# 5      0.000000
# 6      0.792963
# 7      0.459582
# 8      0.000000
# 9      0.831096
# 10     0.697893
# 11     0.504391
# 12     0.537896
# 13     0.219396
# 14     0.000000
# 15     0.402592
# 16     0.360502
# 17     0.000000
# 18     0.506723
# 19     0.237401
# 20     0.109226
# 21     0.661137
# 22     0.318608
# 23     0.000000
# 24     0.501181
# 25     0.357529
# 26     0.258129
# 27     0.756093
# 28     0.585788
# 29     0.000000

# %%
# Cell 4: Pivot Tables

# Pivot for Mean Cosine Similarity
pivot_mean = df.pivot(
    index=["query_index", "category"],
    columns="system",
    values="cosine_mean",
)


print("\n--- Pivot Table: Mean Cosine Similarity ---")
display(pivot_mean)
# Out:
# --- Pivot Table: Mean Cosine Similarity ---
# system                                                 LitSense2    PubMed  \
# query_index category
# 0           Terminology Gap                             0.462095  0.000000
# 1           Multi-Hop Concept Queries                   0.483741  0.000000
# 2           Clinical Treatment Query                    0.459582  0.000000
# 3           Lay-Language Clinical Description           0.697893  0.504391
# 4           Pipeline / Workflow Queries                 0.219396  0.000000
# 5           Resource-Constrained Setting Queries        0.360502  0.000000
# 6           Robustness / Generalization Queries         0.237401  0.109226
# 7           Human–AI Interaction Queries                0.318608  0.000000
# 8           Ethical / Fairness-Aware Modeling Queries   0.357529  0.258129
# 9           Intervention Optimization Queries           0.585788  0.000000
#
# system                                                 VectorSage
# query_index category
# 0           Terminology Gap                              0.470327
# 1           Multi-Hop Concept Queries                    0.651821
# 2           Clinical Treatment Query                     0.792963
# 3           Lay-Language Clinical Description            0.831096
# 4           Pipeline / Workflow Queries                  0.537896
# 5           Resource-Constrained Setting Queries         0.402592
# 6           Robustness / Generalization Queries          0.506723
# 7           Human–AI Interaction Queries                 0.661137
# 8           Ethical / Fairness-Aware Modeling Queries    0.501181
# 9           Intervention Optimization Queries            0.756093

# %%
# Visualization: mean cosine similarity per category and system
import matplotlib.pyplot as plt
import seaborn as sns

# Use pivot_mean if available; if not, recompute from df
try:
    pivot_to_plot = pivot_mean.copy()
except NameError:
    pivot_to_plot = df.pivot(
        index=["query_index", "category"],
        columns="system",
        values="cosine_mean",
    )

# Flatten index so we can use category labels on x-axis
pivot_plot = pivot_to_plot.reset_index()

# Get seaborn deep palette
deep_palette = sns.color_palette("deep")

fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(len(pivot_plot))
width = 0.25

ax.bar(x - width, pivot_plot["VectorSage"], width, label="VectorSage", color=deep_palette[0])
ax.bar(x,         pivot_plot["LitSense2"],  width, label="LitSense2", color=deep_palette[1])
ax.bar(x + width, pivot_plot["PubMed"],     width, label="PubMed", color=deep_palette[2])

ax.set_xticks(x)
ax.set_xticklabels(pivot_plot["category"], rotation=25, ha="right")
ax.set_ylabel("Mean cosine similarity")
ax.set_title("")
ax.legend()

# Remove spines (box)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
#ax.tick_params(axis='both', which='major', width=2, length=6)

# Increase tick line thickness (major ticks)
ax.tick_params(axis='both', which='major', width=2, length=6)
# Increase minor tick line thickness
ax.tick_params(axis='both', which='minor', width=3, length=4)

plt.tight_layout()
plt.savefig('./Figures/mean_cosine_similarity_per_category_v1.tiff', dpi=300, bbox_inches='tight')
plt.savefig('./Figures/mean_cosine_similarity_per_category_v1.svg', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Visualization: overall mean cosine similarity per system
import matplotlib.pyplot as plt
import seaborn as sns

# Compute overall mean cosine similarity per system
mean_per_system = df.groupby("system")["cosine_mean"].mean().reindex(["VectorSage", "LitSense2", "PubMed"])

# Get seaborn deep palette
deep_palette = sns.color_palette("deep")

fig, ax = plt.subplots(figsize=(6, 4))

ax.bar(mean_per_system.index, mean_per_system.values, color=[deep_palette[0], deep_palette[1], deep_palette[2]])
ax.set_ylabel("Mean cosine similarity")
ax.set_title("")

# Remove spines (box)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
#ax.tick_params(axis='both', which='major', width=2, length=6)

# Increase tick line thickness (major ticks)
ax.tick_params(axis='both', which='major', width=2, length=6)
# Increase minor tick line thickness
ax.tick_params(axis='both', which='minor', width=3, length=4)

plt.tight_layout()
plt.savefig('./Figures/overall_mean_cosine_similarity_per_system_v1.tiff', dpi=300, bbox_inches='tight')
plt.savefig('./Figures/overall_mean_cosine_similarity_per_system_v1.svg', dpi=300, bbox_inches='tight')
plt.show()




mean_per_system
# Out:
# system
# VectorSage    0.611183
# LitSense2     0.418253
# PubMed        0.087175
# Name: cosine_mean, dtype: float64

# %%
# Per-document similarities: one row per query–system–document (no averaging)

rows_docs = []
systems = ["VectorSage", "LitSense2", "PubMed"]

print("Computing per-document similarities...")

for query_index, entry in enumerate(results):
    query = entry.get("query", "")
    category = entry.get("category", "")
    sources = entry.get("sources", {})

    if not query:
        continue

    # Encode query once per entry
    q_emb = encode_texts([query])  # shape: (1, d)

    for sys in systems:
        docs_raw = sources.get(sys, []) or []

        if not docs_raw:
            # Represent a "no result" as a single empty doc so it appears explicitly
            docs_raw = [""]

        # Use empty string as-is for embedding so similarity stays low
        docs_for_embed = [doc if isinstance(doc, str) else "" for doc in docs_raw]

        doc_embs = encode_texts(docs_for_embed)  # shape: (k, d)
        sims = cosine_similarity(q_emb, doc_embs)[0]  # shape: (k,)

        for doc_idx, (doc_text, sim) in enumerate(zip(docs_raw, sims)):
            rows_docs.append({
                "query_index": query_index,
                "query": query,
                "category": category,
                "system": sys,
                "doc_index": doc_idx,
                "title": doc_text,
                "cosine": float(sim),
            })

df_docs = pd.DataFrame(rows_docs)
print("Per-document DataFrame shape:", df_docs.shape)
display(df_docs.head())
# Out:
# Computing per-document similarities...
# Per-document DataFrame shape: (73, 7)
#    query_index                                              query  \
# 0            0  Automated systems interpreting chest scans to ...
# 1            0  Automated systems interpreting chest scans to ...
# 2            0  Automated systems interpreting chest scans to ...
# 3            0  Automated systems interpreting chest scans to ...
# 4            0  Automated systems interpreting chest scans to ...
#
#           category      system  doc_index  \
# 0  Terminology Gap  VectorSage          0
# 1  Terminology Gap  VectorSage          1
# 2  Terminology Gap  VectorSage          2
# 3  Terminology Gap   LitSense2          0
# 4  Terminology Gap   LitSense2          1
#
#                                                title    cosine
# 0  Automatic definition of the central-chest lymp...  0.496890
# 1  F-18 fluorodeoxyglucose chest uptake in lung i...  0.439493
# 2  What did we learn from two decades of chest co...  0.474600
# 3  GraphCovidNet: A graph neural network based mo...  0.544706
# 4  A Systematic Literature Review to Determine Ga...  0.349524

# %%
# Per-document similarities: one row per query–system–document (no averaging)

rows_docs = []
systems = ["VectorSage", "LitSense2", "PubMed"]

print("Computing per-document similarities...")

for query_index, entry in enumerate(results):
    query = entry.get("query", "")
    category = entry.get("category", "")
    sources = entry.get("sources", {})

    if not query:
        continue

    # Encode query once per entry
    q_emb = encode_texts([query])  # shape: (1, d)

    for sys in systems:
        docs_raw = sources.get(sys, []) or []

        if not docs_raw:
            # Represent a "no result" as a single empty doc so it appears explicitly
            docs_raw = [""]

        # Use empty string as-is for embedding so similarity stays low
        docs_for_embed = [doc if isinstance(doc, str) else "" for doc in docs_raw]

        doc_embs = encode_texts(docs_for_embed)  # shape: (k, d)
        sims = cosine_similarity(q_emb, doc_embs)[0]  # shape: (k,)

        for doc_idx, (doc_text, sim) in enumerate(zip(docs_raw, sims)):
            rows_docs.append({
                "query_index": query_index,
                "query": query,
                "category": category,
                "system": sys,
                "doc_index": doc_idx,
                "title": doc_text,
                "cosine": float(sim),
            })

df_docs = pd.DataFrame(rows_docs)
print("Per-document DataFrame shape:", df_docs.shape)
display(df_docs.head())

# Per-document labeling and JSON export + visualization

def success_label_doc(score: float) -> str:
    if score >= 0.70:
        return "Relevant"
    elif score >= 0.50:
        return "Partially relevant"
    elif score >= 0.25:
        return "Weakly relevant"
    else:
        return "Irrelevant"

if "cosine" not in df_docs.columns:
    raise ValueError("df_docs must contain a 'cosine' column with per-document similarities.")

# Label each individual document
df_docs_labeled = df_docs.copy()
df_docs_labeled["success_label"] = df_docs_labeled["cosine"].apply(success_label_doc)

display(df_docs_labeled.head())

# Build a JSON structure with labels per query, per system, per document
labeled_doc_results = []
for q_idx, group_q in df_docs_labeled.groupby("query_index"):
    entry = {
        "query_index": int(q_idx),
        "query": group_q["query"].iloc[0],
        "category": group_q["category"].iloc[0],
        "systems": {},
    }
    for sys, group_sys in group_q.groupby("system"):
        docs_list = []
        for _, row in group_sys.sort_values("doc_index").iterrows():
            docs_list.append({
                "doc_index": int(row["doc_index"]),
                "title": row["title"],
                "cosine": float(row["cosine"]),
                "label": row["success_label"],
            })
        entry["systems"][sys] = docs_list
    labeled_doc_results.append(entry)

output_docs_path = "./data/query_results_docs_scored_v1.json"
with open(output_docs_path, "w", encoding="utf-8") as f:
    json.dump({"results": labeled_doc_results}, f, indent=2, ensure_ascii=False)

print(f"Wrote per-document labeled results to {output_docs_path}")

# Visualization: per-document label distribution per system (percentages)
import seaborn as sns

label_counts_docs = (
    df_docs_labeled
    .groupby(["system", "success_label"])
    .size()
    .reset_index(name="count")
)

total_per_system_docs = label_counts_docs.groupby("system")["count"].sum()

label_order = [
    "Irrelevant",
    "Weakly relevant",
    "Partially relevant",
    "Relevant"
]

# Get seaborn deep palette
deep_palette = sns.color_palette("deep")
label_colors = {
    "Relevant": deep_palette[2],
    "Partially relevant": deep_palette[0],
    "Weakly relevant": deep_palette[1],
    "Irrelevant": deep_palette[3]
}

systems_docs = sorted(df_docs_labeled["system"].unique())

fig, ax = plt.subplots(figsize=(8, 5))

bottom = np.zeros(len(systems_docs))

for label in label_order:
    counts = []
    percents = []
    for i, sys in enumerate(systems_docs):
        row = label_counts_docs[(label_counts_docs["system"] == sys) & (label_counts_docs["success_label"] == label)]
        c = int(row["count"].iloc[0]) if not row.empty else 0
        counts.append(c)
        total = int(total_per_system_docs.loc[sys]) if sys in total_per_system_docs else 0
        perc = (c / total * 100) if total > 0 else 0.0
        percents.append(perc)

    counts = np.array(counts)
    bars = ax.bar(systems_docs, counts, bottom=bottom, label=label, color=label_colors[label])

    for i, bar in enumerate(bars):
        if counts[i] == 0:
            continue
        height = bar.get_height()
        y = bar.get_y() + height / 2
        ax.text(bar.get_x() + bar.get_width() / 2, y, f"{percents[i]:.0f}%",
                ha="center", va="center", fontsize=9, color="white")

    bottom += counts

ax.set_ylabel("Number of documents")
ax.set_title("")
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1], title="Label")

# Remove spines (box)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
#ax.tick_params(axis='both', which='major', width=2, length=6)

# Increase tick line thickness
ax.tick_params(axis='both', which='major', width=2, length=6)

plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('./Figures/per_document_relevance_label_distribution_v1.tiff', dpi=300, bbox_inches='tight')
plt.savefig('./Figures/per_document_relevance_label_distribution_v1.svg', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Computing per-document similarities...
# Per-document DataFrame shape: (73, 7)
#    query_index                                              query  \
# 0            0  Automated systems interpreting chest scans to ...
# 1            0  Automated systems interpreting chest scans to ...
# 2            0  Automated systems interpreting chest scans to ...
# 3            0  Automated systems interpreting chest scans to ...
# 4            0  Automated systems interpreting chest scans to ...
#
#           category      system  doc_index  \
# 0  Terminology Gap  VectorSage          0
# 1  Terminology Gap  VectorSage          1
# 2  Terminology Gap  VectorSage          2
# 3  Terminology Gap   LitSense2          0
# 4  Terminology Gap   LitSense2          1
#
#                                                title    cosine
# 0  Automatic definition of the central-chest lymp...  0.496890
# 1  F-18 fluorodeoxyglucose chest uptake in lung i...  0.439493
# 2  What did we learn from two decades of chest co...  0.474600
# 3  GraphCovidNet: A graph neural network based mo...  0.544706
# 4  A Systematic Literature Review to Determine Ga...  0.349524
#    query_index                                              query  \
# 0            0  Automated systems interpreting chest scans to ...
# 1            0  Automated systems interpreting chest scans to ...
# 2            0  Automated systems interpreting chest scans to ...
# 3            0  Automated systems interpreting chest scans to ...
# 4            0  Automated systems interpreting chest scans to ...
#
#           category      system  doc_index  \
# 0  Terminology Gap  VectorSage          0
# 1  Terminology Gap  VectorSage          1
# 2  Terminology Gap  VectorSage          2
# 3  Terminology Gap   LitSense2          0
# 4  Terminology Gap   LitSense2          1
#
#                                                title    cosine  \
# 0  Automatic definition of the central-chest lymp...  0.496890
# 1  F-18 fluorodeoxyglucose chest uptake in lung i...  0.439493
# 2  What did we learn from two decades of chest co...  0.474600
# 3  GraphCovidNet: A graph neural network based mo...  0.544706
# 4  A Systematic Literature Review to Determine Ga...  0.349524
#
#         success_label
# 0     Weakly relevant
# 1     Weakly relevant
# 2     Weakly relevant
# 3  Partially relevant
# 4     Weakly relevant
# Wrote per-document labeled results to ./data/query_results_docs_scored_v1.json

# %%
# Combined visualization: first figure on top, two others below side-by-side
import matplotlib.pyplot as plt
import seaborn as sns


system_display = {
    "VectorSage": "VectorSage",
    "LitSense2": "LitSense2",
    "PubMed": "PubMed",
        "VectorSage": "VectorSage",
}
# Get seaborn deep palette
deep_palette = sns.color_palette("deep")

# Create figure with GridSpec: 2 rows, 2 columns
fig = plt.figure(figsize=(14, 11))
gs = fig.add_gridspec(2, 2, hspace=0.5, wspace=0.3)

# Top plot spans both columns
ax1 = fig.add_subplot(gs[0, :])

# Bottom plots: left and right
ax2 = fig.add_subplot(gs[1, 0])
ax3 = fig.add_subplot(gs[1, 1])

# --- TOP PLOT: Mean cosine similarity per category and system ---
pivot_plot = pivot_mean.reset_index()

x = np.arange(len(pivot_plot))
width = 0.25
print(pivot_plot)
ax1.bar(x - width, pivot_plot["VectorSage"], width, label="VectorSage", color=deep_palette[0])
ax1.bar(x,         pivot_plot["LitSense2"],  width, label="LitSense2", color=deep_palette[1])
ax1.bar(x + width, pivot_plot["PubMed"],     width, label="PubMed", color=deep_palette[2])

ax1.set_xticks(x)
ax1.set_xticklabels(pivot_plot["category"], rotation=25, ha="right", fontsize=9)
ax1.set_ylabel("Mean cosine similarity")
ax1.set_title("")
ax1.legend()

# Remove spines (box)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_linewidth(2)
ax1.spines['bottom'].set_linewidth(2)

# Increase tick line thickness (major ticks)
ax1.tick_params(axis='both', which='major', width=2, length=6)
ax1.tick_params(axis='both', which='minor', width=3, length=4)

# Add (A) label
ax1.text(-0.08, 1.05, '(A)', transform=ax1.transAxes, fontsize=14, fontweight='bold', va='top')

# --- BOTTOM LEFT PLOT: Overall mean cosine similarity per system ---
mean_per_system = df.groupby("system")["cosine_mean"].mean().reindex(["VectorSage", "LitSense2", "PubMed"])
display_index = [system_display[s] for s in mean_per_system.index]

bar_width = 0.8
ax2.bar(display_index, mean_per_system.values, width=bar_width, color=[deep_palette[0], deep_palette[1], deep_palette[2]])
ax2.set_ylabel("Mean cosine similarity")
ax2.set_title("")
ax2.set_xlim(-0.5, 2.5)

# Remove spines (box)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['left'].set_linewidth(2)
ax2.spines['bottom'].set_linewidth(2)

# Increase tick line thickness (major ticks)
ax2.tick_params(axis='both', which='major', width=2, length=6)
ax2.tick_params(axis='both', which='minor', width=3, length=4)

# Add (B) label
ax2.text(-0.15, 1.05, '(B)', transform=ax2.transAxes, fontsize=14, fontweight='bold', va='top')
ax2.annotate(f"{mean_per_system['VectorSage']:.3f}", xy=(0, mean_per_system['VectorSage']), xytext=(-0.1, mean_per_system['VectorSage'] + 0.01),
                fontsize=10, color='black')
ax2.annotate(f"{mean_per_system['LitSense2']:.3f}", xy=(1, mean_per_system['LitSense2']), xytext=(0.9, mean_per_system['LitSense2'] + 0.01),
                fontsize=10, color='black')
ax2.annotate(f"{mean_per_system['PubMed']:.3f}", xy=(2, mean_per_system['PubMed']), xytext=(1.9, mean_per_system['PubMed'] + 0.01),
                fontsize=10, color='black')
# --- BOTTOM RIGHT PLOT: Per-document label distribution ---
label_counts_docs = (
    df_docs_labeled
    .groupby(["system", "success_label"])
    .size()
    .reset_index(name="count")
)

total_per_system_docs = label_counts_docs.groupby("system")["count"].sum()

label_order = [
    "Irrelevant",
    "Weakly relevant",
    "Partially relevant",
    "Relevant"
]

label_colors = {
    "Relevant": deep_palette[2],
    "Partially relevant": deep_palette[0],
    "Weakly relevant": deep_palette[1],
    "Irrelevant": deep_palette[3]
}

# systems_docs = sorted(df_docs_labeled["system"].unique())
systems_docs = systems

bottom = np.zeros(len(systems_docs))

for label in label_order:
    counts = []
    percents = []
    for i, sys in enumerate(systems_docs):
        row = label_counts_docs[(label_counts_docs["system"] == sys) & (label_counts_docs["success_label"] == label)]
        c = int(row["count"].iloc[0]) if not row.empty else 0
        counts.append(c)
        total = int(total_per_system_docs.loc[sys]) if sys in total_per_system_docs else 0
        perc = (c / total * 100) if total > 0 else 0.0
        percents.append(perc)


    counts = np.array(counts)
    display_systems = [system_display[s] for s in systems_docs]



    bars = ax3.bar(display_systems, counts, width=bar_width, bottom=bottom, label=label, color=label_colors[label])

    for i, bar in enumerate(bars):
        if counts[i] == 0:
            continue
        height = bar.get_height()
        y = bar.get_y() + height / 2
        ax3.text(bar.get_x() + bar.get_width() / 2, y, f"{percents[i]:.0f}%",
                ha="center", va="center", fontsize=9, color="white")

    bottom += counts

ax3.set_ylabel("Number of documents")
ax3.set_title("")
handles, labels = ax3.get_legend_handles_labels()
print(labels)
ax3.legend(handles[::-1], labels[::-1], title="Label", fontsize=8)

# Remove spines (box)
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.spines['left'].set_linewidth(2)
ax3.spines['bottom'].set_linewidth(2)

# Increase tick line thickness
ax3.tick_params(axis='both', which='major', width=2, length=6)

# Add (C) label
ax3.text(-0.15, 1.05, '(C)', transform=ax3.transAxes, fontsize=14, fontweight='bold', va='top')



plt.savefig('./Figures/combined_cosine_similarity_figures_v1.tiff', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# system  query_index                                   category  LitSense2  \
# 0                 0                            Terminology Gap   0.462095
# 1                 1                  Multi-Hop Concept Queries   0.483741
# 2                 2                   Clinical Treatment Query   0.459582
# 3                 3          Lay-Language Clinical Description   0.697893
# 4                 4                Pipeline / Workflow Queries   0.219396
# 5                 5       Resource-Constrained Setting Queries   0.360502
# 6                 6        Robustness / Generalization Queries   0.237401
# 7                 7               Human–AI Interaction Queries   0.318608
# 8                 8  Ethical / Fairness-Aware Modeling Queries   0.357529
# 9                 9          Intervention Optimization Queries   0.585788
#
# system    PubMed  VectorSage
# 0       0.000000    0.470327
# 1       0.000000    0.651821
# 2       0.000000    0.792963
# 3       0.504391    0.831096
# 4       0.000000    0.537896
# 5       0.000000    0.402592
# 6       0.109226    0.506723
# 7       0.000000    0.661137
# 8       0.258129    0.501181
# 9       0.000000    0.756093
# ['Irrelevant', 'Weakly relevant', 'Partially relevant', 'Relevant']
